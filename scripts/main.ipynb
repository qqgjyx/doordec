# %%
# ============================================================================
# CONFIGURATION
# ============================================================================

# File paths
ROSTER_PATH = '../data/CY3 Resident List-Updated 01032026.xlsx'
MEMES_PATH = '../data/cat_memes/'
OUTPUT_PATH = '../out/SP26 CY3.pdf'

# Filter settings
BED_SPACE_PREFIX = 'F-3103'  # Filter for bed spaces starting with this

# Design colors
PRIMARY_COLOR = '#1a237e'   # Deep blue
ACCENT_COLOR = '#9fa8da'    # Light blue
TEXT_COLOR = '#1a237e'      # Text color

# Page settings
PAGE_SIZE = (11.69, 8.27)   # A4 horizontal (landscape) dimensions in inches
DPI = 300                   # Print quality

# %%
# ============================================================================
# IMPORTS
# ============================================================================

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageOps
import random
import glob
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.patches as patches
import matplotlib.patheffects as pe

# Optional: For Reddit image crawling
import requests
from urllib.parse import urlparse
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

# %%
# ============================================================================
# OPTIONAL: Download memes from Reddit
# ============================================================================
# Set DOWNLOAD_MEMES = True to download images from Reddit
# Set DOWNLOAD_MEMES = False to skip and use existing memes in MEMES_PATH

DOWNLOAD_MEMES = False  # Change to True to enable downloading

if DOWNLOAD_MEMES:
    import praw
    
    # Reddit API credentials (replace with your own)
    reddit = praw.Reddit(
        client_id='ShnBSk3RTJklCQQsOVX0iw',
        client_secret='kHuwyBg6kotj-dsqLqu0eHiKCXVt-w',
        user_agent='cat_meme_bot',
        read_only=True
    )
    
    def download_image(post) -> bool:
        """Download image from Reddit post"""
        if not post.url.endswith(('.jpg', '.jpeg', '.png', '.gif')):
            return False
        
        filename = os.path.basename(urlparse(post.url).path)
        filepath = os.path.join(MEMES_PATH, filename)
        
        try:
            response = requests.get(post.url, timeout=10)
            if response.status_code == 200:
                with open(filepath, 'wb') as f:
                    f.write(response.content)
                return True
            return False
        except Exception as e:
            print(f"Error downloading {post.url}: {str(e)}")
            return False
    
    # Create memes directory if it doesn't exist
    os.makedirs(MEMES_PATH, exist_ok=True)
    
    # Get posts from subreddit
    subreddit = reddit.subreddit('CatMemes')
    posts = list(subreddit.hot(limit=200))
    
    # Download images using thread pool
    print("Downloading images from Reddit...")
    with ThreadPoolExecutor(max_workers=10) as executor:
        results = list(tqdm(
            executor.map(download_image, posts),
            total=len(posts),
            desc="Downloading images"
        ))
    
    print(f"Successfully downloaded {sum(results)} images")
else:
    print("Skipping Reddit download. Using existing memes in folder.")
# Out:
# Skipping Reddit download. Using existing memes in folder.

# %%
# ============================================================================
# LOAD DATA AND GROUP BY ROOM
# ============================================================================

# Read roster and filter for F-31 bed spaces
roster_df = pd.read_excel(ROSTER_PATH)
filtered_df = roster_df[roster_df['Bed Space'].str.startswith(BED_SPACE_PREFIX, na=False)].copy()

# Extract room numbers (remove trailing letter: F-31-101A -> F-31-101)
def get_room_number(bed_space):
    if pd.isna(bed_space) or not isinstance(bed_space, str):
        return None
    return bed_space[:-1] if bed_space and bed_space[-1].isalpha() else bed_space

filtered_df['Room'] = filtered_df['Bed Space'].apply(get_room_number)

# Group by room
room_groups = []
for room, group in filtered_df.groupby('Room'):
    if room is not None:
        room_groups.append({'room': room, 'residents': group.to_dict('records')})

print(f"Total rooms: {len(room_groups)}")
print(f"Total residents: {len(filtered_df)}")
# Out:
# Total rooms: 1
# Total residents: 2

# %%
# ============================================================================
# HELPER FUNCTIONS (FAST RENDERER)
# ============================================================================

# Precompute a small gradient once (re-used for every page)
_BG_GRADIENT = np.linspace(0, 1, 500).reshape(-1, 1)
_BG_GRADIENT = np.tile(_BG_GRADIENT, (1, 2))

# Cache fitted images (path, w_px, h_px) -> PIL.Image
_IMAGE_CACHE = {}


def _get_fitted_image(image_path, w_px, h_px):
    """Open + center-crop image to exactly (w_px, h_px). Cached for speed."""
    key = (image_path, int(w_px), int(h_px))
    cached = _IMAGE_CACHE.get(key)
    if cached is not None:
        return cached

    img = ImageOps.exif_transpose(Image.open(image_path)).convert('RGB')

    try:
        resample = Image.Resampling.LANCZOS
    except AttributeError:
        resample = Image.LANCZOS

    fitted = ImageOps.fit(img, (int(w_px), int(h_px)), method=resample, centering=(0.5, 0.5))
    _IMAGE_CACHE[key] = fitted
    return fitted


def _draw_name_plate(ax, x, y, w, h, text, align='left', fontsize=44):
    """Draw a rounded name plate on a single axes (axes coords)."""
    if not text:
        return

    plate = patches.FancyBboxPatch(
        (x, y), w, h,
        boxstyle='round,pad=0.010,rounding_size=0.03',
        transform=ax.transAxes,
        facecolor='white',
        edgecolor=ACCENT_COLOR,
        linewidth=2.0,
        alpha=0.90,
        zorder=5,
    )
    plate.set_path_effects([pe.SimplePatchShadow(offset=(2, -2), alpha=0.18), pe.Normal()])
    ax.add_patch(plate)

    pad = 0.018
    if align == 'left':
        tx, ha = x + pad, 'left'
    elif align == 'right':
        tx, ha = x + w - pad, 'right'
    else:
        tx, ha = x + w / 2, 'center'

    t = ax.text(
        tx, y + h / 2, text,
        transform=ax.transAxes,
        ha=ha, va='center',
        fontsize=fontsize,
        fontweight='bold',
        fontfamily='DejaVu Sans',
        color=TEXT_COLOR,
        zorder=6,
    )
    t.set_path_effects([pe.withStroke(linewidth=3, foreground='white')])


def render_horizontal_page(fig, meme_path, name1, name2):
    """Render the full page on ONE axes (fast): background + meme + 2 name plates."""
    ax = fig.add_axes([0, 0, 1, 1])
    ax.set_axis_off()
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)

    # Background (fast)
    ax.imshow(_BG_GRADIENT, cmap='Blues', alpha=0.07, extent=[0, 1, 0, 1], origin='lower', zorder=-3)

    # Subtle diagonal accent
    ax.add_patch(patches.Polygon(
        [(0.00, 0.18), (1.00, 0.46), (1.00, 0.56), (0.00, 0.28)],
        closed=True,
        transform=ax.transAxes,
        facecolor=ACCENT_COLOR,
        edgecolor='none',
        alpha=0.08,
        zorder=-2,
    ))

    # Top/bottom lines
    ax.plot([0.06, 0.94], [0.96, 0.96], transform=ax.transAxes, color=PRIMARY_COLOR, lw=2.5, zorder=-1)
    ax.plot([0.06, 0.94], [0.04, 0.04], transform=ax.transAxes, color=PRIMARY_COLOR, lw=2.5, zorder=-1)

    # Meme box (same geometry every page)
    meme_x, meme_y = 0.22, 0.20
    meme_w, meme_h = 0.56, 0.60

    # Fit image to exact pixel dimensions needed for this figure
    fig_w_px = fig.get_figwidth() * DPI
    fig_h_px = fig.get_figheight() * DPI
    target_w_px = max(1, int(fig_w_px * meme_w))
    target_h_px = max(1, int(fig_h_px * meme_h))

    img_fit = _get_fitted_image(meme_path, target_w_px, target_h_px)
    ax.imshow(img_fit, extent=[meme_x, meme_x + meme_w, meme_y, meme_y + meme_h], zorder=1)

    # Double frame (rectangles)
    ax.add_patch(patches.Rectangle(
        (meme_x, meme_y), meme_w, meme_h,
        transform=ax.transAxes,
        fill=False,
        linewidth=3.5,
        edgecolor=PRIMARY_COLOR,
        zorder=2,
    ))
    ax.add_patch(patches.Rectangle(
        (meme_x - 0.010, meme_y - 0.010), meme_w + 0.020, meme_h + 0.020,
        transform=ax.transAxes,
        fill=False,
        linewidth=1.8,
        edgecolor=ACCENT_COLOR,
        zorder=1,
    ))

    # Name plates (moved inward)
    _draw_name_plate(ax, x=0.08, y=0.76, w=0.44, h=0.14, text=name1, align='left', fontsize=44)
    _draw_name_plate(ax, x=0.48, y=0.10, w=0.44, h=0.14, text=name2, align='right', fontsize=44)

# %%
# ============================================================================
# PAGE LAYOUT FUNCTIONS - HORIZONTAL A4 DESIGN
# ============================================================================

def create_horizontal_page(fig, residents, meme_path):
    """Horizontal layout: name up-left, meme between, name down-right."""

    def get_name(resident):
        preferred = resident.get('Preferred Name', '')
        if pd.isna(preferred) or str(preferred).strip() == '':
            return str(resident.get('Given Name', '')).strip()
        return str(preferred).strip()

    n = len(residents)
    name1 = get_name(residents[0]) if n >= 1 else ''
    name2 = get_name(residents[1]) if n >= 2 else ''

    # If there are 3+ residents in the same room, indicate it (rare, but safe)
    if n > 2 and name2:
        name2 = f"{name2}  (+{n-2})"

    render_horizontal_page(fig, meme_path=meme_path, name1=name1, name2=name2)


def create_room_page(fig, residents, meme_paths):
    """Create one page per room."""
    meme_path = meme_paths[0] if meme_paths else None
    if meme_path:
        create_horizontal_page(fig, residents, meme_path)

# %%
# ============================================================================
# GENERATE PDF
# ============================================================================

# Load memes
extensions = ['*.jpg', '*.jpeg', '*.png', '*.gif']
memes = []
for ext in extensions:
    memes.extend(glob.glob(f"{MEMES_PATH}/{ext}"))
random.shuffle(memes)

# Create output directory
os.makedirs('../out', exist_ok=True)

# Generate PDF with progress bar
meme_idx = 0
with PdfPages(OUTPUT_PATH) as pdf:
    # Progress bar for PDF generation
    with tqdm(total=len(room_groups), desc="Generating PDF pages", unit="page") as pbar:
        for room_group in room_groups:
            residents = room_group['residents']
            
            # Check if we have enough memes
            if meme_idx >= len(memes):
                print(f"\nWarning: Ran out of memes at room {room_group['room']}")
                break
            
            # Use one meme per page (for horizontal layout)
            room_memes = [memes[meme_idx]]
            meme_idx += 1
            
            # Create page
            fig = plt.figure(figsize=PAGE_SIZE, dpi=DPI)
            create_room_page(fig, residents, room_memes)

            # Faster save: avoid tight bbox (we already control full-page layout)
            pdf.savefig(fig, dpi=DPI)
            plt.close(fig)

            # Update progress bar
            pbar.update(1)

print(f"\n✓ PDF generated: {OUTPUT_PATH}")
print(f"✓ Rooms processed: {len(room_groups)}")
print(f"✓ Memes used: {meme_idx}")
# Out:
# Generating PDF pages: 100%|██████████| 1/1 [00:00<00:00,  4.49page/s]
# ✓ PDF generated: ../out/SP26 CY3.pdf
# ✓ Rooms processed: 1
# ✓ Memes used: 1
